# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('all_train_df.csv')
df
# Out:
#                      id   cell_id cell_type  \
# 0        00001756c60be8  1862f0a6      code
# 1        00001756c60be8  2a9e43d6      code
# 2        00001756c60be8  038b763d      code
# 3        00001756c60be8  2eefe0ef      code
# 4        00001756c60be8  0beab1cd      code
# ...                 ...       ...       ...
# 6370645  fffe1d764579d5  0d770d6b  markdown
# 6370646  fffe1d764579d5  d45ddc62  markdown
# 6370647  fffe1d764579d5  1a63248d  markdown
# 6370648  fffe1d764579d5  a8ffc8b4  markdown
# 6370649  fffe1d764579d5  4e2d4c2d  markdown
#
#                                                     source  rank ancestor_id  \
# 0        # This Python 3 environment comes with many he...   0.0    945aea18
# 1        import numpy as np\nimport pandas as pd\nimpor...   2.0    945aea18
# 2        import warnings\nwarnings.filterwarnings('igno...   4.0    945aea18
# 3            matplotlib.rcParams.update({'font.size': 14})   6.0    945aea18
# ...

# %%
df[df['id'] == '00001756c60be8']
# Out:
#                 id   cell_id cell_type  \
# 0   00001756c60be8  1862f0a6      code
# 1   00001756c60be8  2a9e43d6      code
# 2   00001756c60be8  038b763d      code
# 3   00001756c60be8  2eefe0ef      code
# 4   00001756c60be8  0beab1cd      code
# 5   00001756c60be8  9a78ab76      code
# 6   00001756c60be8  ebe125d5      code
# 7   00001756c60be8  d9dced8b      code
# 8   00001756c60be8  86497fe1      code
# 9   00001756c60be8  e2c8e725      code
# 10  00001756c60be8  ff7c44ed      code
# 11  00001756c60be8  0e7c906e      code
# 12  00001756c60be8  dd0c804a      code
# 13  00001756c60be8  781bbf3c      code
# 14  00001756c60be8  bd94f005      code
# 15  00001756c60be8  62638fba      code
# 16  00001756c60be8  bb69e88c      code
# 17  00001756c60be8  6b5664c7      code
# 18  00001756c60be8  23783525      code
# 19  00001756c60be8  8522781a      code
# 20  00001756c60be8  8ca8392c      code
# 21  00001756c60be8  17ec3fc4      code
# 22  00001756c60be8  76512d50      code
# ...
